# %%
import pandas as pd

# %%
df = pd.read_csv('NBA_data_cleaned.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Full Name', 'Team', 'Position', 'Age', 'Games Played',
#        'MPG', 'TO%', 'FTA', 'FT%', '2PA', '2P%', '3PA', '3P%', 'eFG%', 'PPG',
#        'RPG', 'APG', 'SPG', 'BPG', 'Offensive Rating', 'Defensive Rating'],
#       dtype='object')

# %%
df.head()
# Out:
#   Unnamed: 0                 Full Name Team Position    Age  Games Played  \
# 0          1              Steven Adams  Okc        C  27.07          63.0
# 1          2               Bam Adebayo  Mia      C-F  23.08          72.0
# 2          3         LaMarcus Aldridge  San      F-C  35.07          53.0
# 3          4            Kyle Alexander  Mia      F-C  23.81           2.0
# 4          5  Nickeil Alexander-Walker  Nor        G  21.95          47.0
#
#     MPG   TO%    FTA    FT%  ...    3PA    3P%   eFG%   PPG   RPG  APG   SPG  \
# 0  26.7  14.4  201.0  0.582  ...    3.0  0.333  0.593  10.9   9.3  2.3  0.81
# 1  33.6  17.5  382.0  0.691  ...   14.0  0.143  0.558  15.9  10.2  5.1  1.14
# 2  33.1   7.8  191.0  0.827  ...  157.0  0.389  0.531  18.9   7.4  2.4  0.68
# 3   6.7  33.3    0.0  0.000  ...    0.0  0.000  0.500   1.0   1.5  0.0  0.00
# 4  12.6  16.1   37.0  0.676  ...  133.0  0.346  0.455   5.7   1.8  1.9  0.36
#
#     BPG  Offensive Rating  Defensive Rating
# ...

# %%
df.groupby(['Position']).mean().sort_values('PPG')
# Out:
#                 Age  Games Played        MPG        TO%         FTA       FT%  \
# Position
# 0         29.550000     60.000000  17.400000  11.500000   73.000000  0.740000
# G-F       26.203385     38.046154  18.407692  12.233846   65.830769  0.714215
# F-G       25.147037     44.000000  19.829630  12.448148   87.666667  0.642963
# F-C       25.781471     38.647059  18.200000  14.829412   94.823529  0.678882
# F         27.372840     36.236686  19.847929  12.933728   78.905325  0.712166
# C         27.978333     43.380952  20.945238  13.588095  102.190476  0.664714
# C-F       25.537407     45.037037  19.644444  14.114815  121.222222  0.692778
# G         26.944951     39.651961  20.644118  12.922059   88.539216  0.740716
#
#                  2PA       2P%         3PA       3P%      eFG%       PPG  \
# Position
# 0         117.000000  0.573000  206.000000  0.335000  0.528000  6.600000
# G-F       159.000000  0.463154  133.276923  0.318338  0.481200  7.278462
# ...

# %%
df.sort_values('PPG', ascending = False)[['Full Name','PPG','RPG','APG']]
# Out:
#   File "<ipython-input-16-759131c1b452>", line 1
#     df.sort_values('PPG', ascending = False, 10)[['Full Name','PPG','RPG','APG']]
#                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
df_num = df[['MPG', 'TO%', 'FTA', 'FT%', '2PA', '2P%', '3PA', '3P%', 'eFG%', 'PPG',
       'RPG', 'APG', 'SPG', 'BPG']]

# %%
df_num
# Out:
#       MPG   TO%    FTA    FT%    2PA    2P%    3PA    3P%   eFG%   PPG   RPG  \
# 0    26.7  14.4  201.0  0.582  475.0  0.594    3.0  0.333  0.593  10.9   9.3
# 1    33.6  17.5  382.0  0.691  777.0  0.564   14.0  0.143  0.558  15.9  10.2
# 2    33.1   7.8  191.0  0.827  637.0  0.518  157.0  0.389  0.531  18.9   7.4
# 3     6.7  33.3    0.0  0.000    2.0  0.500    0.0  0.000  0.500   1.0   1.5
# 4    12.6  16.1   37.0  0.676  133.0  0.391  133.0  0.346  0.455   5.7   1.8
# ..    ...   ...    ...    ...    ...    ...    ...    ...    ...   ...   ...
# 565  35.3  16.2  559.0  0.860  681.0  0.501  568.0  0.361  0.519  29.6   4.2
# 566  23.1  11.8  179.0  0.682  405.0  0.575   75.0  0.240  0.542  11.1   7.1
# 567  10.0  11.1   19.0  0.737   72.0  0.569    0.0  0.000  0.569   4.4   3.0
# 568  18.4  11.7  166.0  0.747  385.0  0.613    2.0  0.000  0.610   8.3   7.6
# 569   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN
#
#      APG   SPG   BPG
# 0    2.3  0.81  1.06
# ...

# %%
p = df_num.hist(figsize = (20,20))

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
p = sns.pairplot(df_num)

# %%
plt.figure(figsize = (30,30))
p = sns.heatmap(df_num.corr(), annot = True, cmap = 'RdYlGn')
